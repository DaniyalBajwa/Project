# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('placement.csv')

# %%
data
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
data.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['cgpa'],data['iq'],c=data['placement'])

# %%
data.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
x=data.iloc[:,0:3]

# %%
x
# Out:
#     Unnamed: 0  cgpa     iq
# 0            0   6.8  123.0
# 1            1   5.9  106.0
# 2            2   5.3  121.0
# 3            3   7.4  132.0
# 4            4   5.8  142.0
# ..         ...   ...    ...
# 95          95   4.3  200.0
# 96          96   4.4   42.0
# 97          97   6.7  182.0
# 98          98   6.3  103.0
# 99          99   6.2  113.0
#
# [100 rows x 3 columns]

# %%
y=data.iloc[:,-1]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
X_train
# Out:
#     Unnamed: 0  cgpa     iq
# 84          84   5.7  169.0
# 50          50   3.5  233.0
# 51          51   4.8  141.0
# 29          29   7.0  112.0
# 38          38   6.5  160.0
# ..         ...   ...    ...
# 32          32   7.0  139.0
# 78          78   6.1   81.0
# 71          71   6.1  132.0
# 42          42   7.6   89.0
# 2            2   5.3  121.0
#
# [90 rows x 3 columns]

# %%
y_train
# Out:
# 84    0
# 50    0
# 51    0
# 29    1
# 38    1
#      ..
# 32    1
# 78    0
# 71    1
# 42    1
# 2     0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     Unnamed: 0  cgpa     iq
# 41          41   5.4  114.0
# 46          46   5.3  114.0
# 76          76   4.9  155.0
# 62          62   6.0  102.0
# 14          14   6.1  103.0
# 43          43   6.8  141.0
# 18          18   4.0  100.0
# 5            5   7.1   48.0
# 24          24   4.7  121.0
# 0            0   6.8  123.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %% [raw]
# X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
#     Unnamed: 0  cgpa     iq
# 84          84   5.7  169.0
# 50          50   3.5  233.0
# 51          51   4.8  141.0
# 29          29   7.0  112.0
# 38          38   6.5  160.0
# ..         ...   ...    ...
# 32          32   7.0  139.0
# 78          78   6.1   81.0
# 71          71   6.1  132.0
# 42          42   7.6   89.0
# 2            2   5.3  121.0
#
# [90 rows x 3 columns]

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.34342697, -0.31958763,  0.0702217 ],
#        [ 0.55541892, -0.42268041,  0.0702217 ],
#        [ 1.82737064, -0.83505155,  1.58553216],
#        [ 1.23379317,  0.29896907, -0.37328379],
#        [-0.80132959,  0.40206186, -0.336325  ],
#        [ 0.42822375,  1.12371134,  1.06810908],
#        [-0.63173602, -1.7628866 , -0.44720138],
#        [-1.1829151 ,  1.43298969, -2.36905854],
#        [-0.37734568, -1.04123711,  0.32893324],
#        [-1.39490706,  1.12371134,  0.40285083]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
df=LogisticRegression()

# %%
df.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=df.predict(X_test)
# Out:
# C:\Users\ccomputers\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
y_test
# Out:
# 41    0
# 46    0
# 76    0
# 62    0
# 14    0
# 43    1
# 18    0
# 5     1
# 24    0
# 0     1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
plot_decision_regions(X_train, y_train.value, clf=df, legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 plot_decision_regions(X_train, y_train.value, clf=df, legend=2)
#
# NameError: name 'plot_decision_regions' is not defined

# %%
plt.scatter(y_test, y_pred, color='Green')

plt.title('Predicted vs Actual Placements')
plt.xlabel('Actual Placement')
plt.ylabel('Predicted Placement')
plt.show()

# %%
import pickle
pickle.dump(df, open('placement_model.pkl', 'wb') )

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 pickel
#
# NameError: name 'pickel' is not defined
